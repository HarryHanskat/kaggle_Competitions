# %% [markdown]
# ## Outline
#
# 1. Analyze and define what each data set is doing and how it may be relevant. What sories might be told.
# 2. Preprocess data
# 3. EDA Exploratory Data Analysis
#     - Define steps to this analysis when we get there.
#     - Can I potentially use Tableau for some exploration?

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
districts = pd.read_csv("districts_info.csv")

# %%
districts.head()
# Out:
#    district_id     state  locale pct_black/hispanic pct_free/reduced  \
# 0         8815  Illinois  Suburb           [0, 0.2[         [0, 0.2[
# 1         2685       NaN     NaN                NaN              NaN
# 2         4921      Utah  Suburb           [0, 0.2[       [0.2, 0.4[
# 3         3188       NaN     NaN                NaN              NaN
# 4         2238       NaN     NaN                NaN              NaN
#
#   county_connections_ratio    pp_total_raw
# 0                [0.18, 1[  [14000, 16000[
# 1                      NaN             NaN
# 2                [0.18, 1[    [6000, 8000[
# 3                      NaN             NaN
# 4                      NaN             NaN

# %%
districts.columns
# Out:
# Index([u'district_id', u'state', u'locale', u'pct_black/hispanic',
#        u'pct_free/reduced', u'county_connections_ratio', u'pp_total_raw'],
#       dtype='object')

# %%
products = pd.read_csv("products_info.csv")

# %%
products.head()
# Out:
#    LP ID                           URL  Product Name  Provider/Company Name  \
# 0  13117    https://www.splashmath.com   SplashLearn          StudyPad Inc.
# 1  66933          https://abcmouse.com  ABCmouse.com  Age of Learning, Inc
# 2  50479         https://www.abcya.com        ABCya!         ABCya.com, LLC
# 3  92993         http://www.aleks.com/         ALEKS    McGraw-Hill PreK-12
# 4  73104  https://www.achieve3000.com/   Achieve3000            Achieve3000
#
#             Sector(s)                         Primary Essential Function
# 0             PreK-12                    LC - Digital Learning Platforms
# 1             PreK-12                    LC - Digital Learning Platforms
# 2             PreK-12  LC - Sites, Resources & Reference - Games & Si...
# 3  PreK-12; Higher Ed                    LC - Digital Learning Platforms
# 4             PreK-12                    LC - Digital Learning Platforms

# %%
products.columns
# Out:
# Index([u'LP ID', u'URL', u'Product Name', u'Provider/Company Name',
#        u'Sector(s)', u'Primary Essential Function'],
#       dtype='object')

# %%
products.describe
# Out:
# <bound method DataFrame.describe of      LP ID                                                URL  \
# 0    13117                         https://www.splashmath.com
# 1    66933                               https://abcmouse.com
# 2    50479                              https://www.abcya.com
# 3    92993                              http://www.aleks.com/
# 4    73104                       https://www.achieve3000.com/
# 5    37600                      http://www.activelylearn.com/
# 6    18663                         http://www.adaptedmind.com
# 7    65131                            http://www.amplify.com/
# 8    26491                            http://www.answers.com/
# 9    56441                             http://www.audible.com
# 10   89802                               http://bartleby.com/
# 11   72703                           http://betterlesson.com/
# 12   76889                        https://www.blackboard.com/
# 13   49563                           https://bookcreator.com/
# ...

# %%
engagement1 = pd.read_csv("engagement_data/9927.csv")

# %%
engagement1.head()
# Out:
#          time  lp_id  pct_access  engagement_index
# 0  2020-01-01  77713        0.07              1.09
# 1  2020-01-01  99916        3.21            127.76
# 2  2020-01-01  16406        0.04              3.49
# 3  2020-01-01  97280        0.07              4.59
# 4  2020-01-01  32348        0.00               NaN

# %%
#engagement1.describe
# Out:
# <bound method DataFrame.describe of              time  lp_id  pct_access  engagement_index
# 0      2020-01-01  77713        0.07              1.09
# 1      2020-01-01  99916        3.21            127.76
# 2      2020-01-01  16406        0.04              3.49
# 3      2020-01-01  97280        0.07              4.59
# 4      2020-01-01  32348        0.00               NaN
# 5      2020-01-01  77698        0.09              3.06
# 6      2020-01-01  66950        0.02              0.44
# 7      2020-01-01  33185        0.44             66.61
# 8      2020-01-01  91243        0.02              0.22
# 9      2020-01-01  65358        0.07              1.31
# 10     2020-01-01  49570        0.02              0.22
# 11     2020-01-01  24711        0.15             23.37
# 12     2020-01-01  92918        0.02              0.66
# 13     2020-01-01  37600        0.02              0.87
# 14     2020-01-01  37479        0.00               NaN
# ...
